# %% [markdown]
# # Loan Default Prediction - End-to-End Data Science Project

# %% [markdown]
# ## Step 1: Problem Statement
# Predict whether a customer will default on a loan based on financial data.

# %% [markdown]
# ## Step 2: Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 3: Load Dataset

# %%
df = pd.read_csv('loan_data.csv')
df.head()

# %% [markdown]
# ## Step 4: Explore Data

# %%
df.info()
df.describe()

# %% [markdown]
# ## Step 5: Data Cleaning

# %%
df = df.drop_duplicates()
df = df.fillna(method='ffill')

# %% [markdown]
# ## Step 6: EDA

# %%
sns.countplot(x='Loan_Status', data=df)
plt.show()

sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Step 7: Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in df.select_dtypes(include='object'):
    df[col] = le.fit_transform(df[col])

# %% [markdown]
# ## Step 8: Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Step 9: Model Building

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)

# %% [markdown]
# ## Step 10: Prediction

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Step 11: Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# %% [markdown]
# ## Step 12: Insights
# 1. Income affects loan approval.
# 2. Credit history is important.
# 3. Some features strongly influence predictions.
